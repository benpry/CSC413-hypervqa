# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/CSC413-HyperVQA
# Out:
# /content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA

# %%
# !bash ./Anaconda3-2020.11-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# # All requested packages already installed.
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Anaconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Anaconda3: /usr/local

# %%
# %%bash
# export NMN=$PWD
# conda env create -f environment.yml
# source activate sysgen
# pip install -e .
# Out:
# ...
# Solving environment: ...working... done
#
# ...
# libidn2-2.3.0        | 86 KB     | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# gmp-6.2.1            | 539 KB    | ########## | 100%
# ca-certificates-2021 | 114 KB    | ########## | 100%
# cuda90-1.0           | 3 KB      | ########## | 100%
# certifi-2020.12.5    | 140 KB    | ########## | 100%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
# cudatoolkit-10.2.89  | 365.1 MB  | ########## | 100%
# openssl-1.1.1k       | 2.5 MB    | ########## | 100%
# pip-21.0.1           | 1.8 MB    | ########## | 100%
# lz4-c-1.9.3          | 186 KB    | ########## | 100%
# openh264-2.1.0       | 722 KB    | ########## | 100%
# python-3.6.13        | 29.7 MB   | ########## | 100%
# olefile-0.46         | 48 KB     | ########## | 100%
# readline-8.1         | 362 KB    | ########## | 100%
# libuv-1.40.0         | 736 KB    | ########## | 100%
# nettle-3.7.2         | 811 KB    | ########## | 100%
# ...

# %%
# %%bash
# source activate sysgen
#
# python
# import sys
# # some simple python commands
# sys.path.append('/usr/local/lib/python3.6/site-packages')
# print(sys.path)
#
# print("Python version")
# print(sys.version)
# Out:
# ['', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '/usr/local/lib/python3.6/site-packages']
# Python version
# 3.6.13 |Anaconda, Inc.| (default, Feb 23 2021, 21:15:04)
# [GCC 7.3.0]

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.

# %%
# %%bash
# # replace film_flatqa with the script that runs the model we want
# source activate sysgen
# dos2unix scripts/train/hypervqa_flatqa.sh
# chmod +x scripts/train/hypervqa_flatqa.sh
# export NMN=/content/drive/MyDrive/CSC413-HyperVQA
#
# scripts/train/hypervqa_flatqa.sh --data_dir data/sqoop-variety_1-repeats_30000/ --checkpoint_path models/v1_model.pt\ --batch_size 256 --num_iterations 10000 --classifier_fc_dims 512
# Out:
# path: ['/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA/scripts', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '../', '/content/drive/MyDrive/CSC413/']
# training device: cuda:0
# Reading features from  data/sqoop-variety_1-repeats_30000/train_features.h5
# Reading questions from  data/sqoop-variety_1-repeats_30000/train_questions.h5
# Reading question data into memory
# Reading features from  data/sqoop-variety_1-repeats_30000/val_features.h5
# Reading questions from  data/sqoop-variety_1-repeats_30000/val_questions.h5
# Reading question data into memory
# num check samples 1024
# num check samples 1000
# num check samples 1024
# num check samples 1000
# num check samples 1024
# ...

# %%
# %%bash
# # replace film_flatqa with the script that runs the model we want
# source activate sysgen
# dos2unix scripts/train/hypervqa_flatqa.sh
# chmod +x scripts/train/hypervqa_flatqa.sh
# export NMN=/content/drive/MyDrive/CSC413-HyperVQA
#
# scripts/train/hypervqa_flatqa.sh --data_dir data/sqoop-variety_2-repeats_15000/ --checkpoint_path models/v2_model.pt\ --batch_size 256 --num_iterations 15000
# Out:
# path: ['/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA/scripts', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '../', '/content/drive/MyDrive/CSC413/']
# training device: cuda:0
# Reading features from  data/sqoop-variety_2-repeats_15000/train_features.h5
# Reading questions from  data/sqoop-variety_2-repeats_15000/train_questions.h5
# Reading question data into memory
# Reading features from  data/sqoop-variety_2-repeats_15000/val_features.h5
# Reading questions from  data/sqoop-variety_2-repeats_15000/val_questions.h5
# Reading question data into memory
# num check samples 1024
# num check samples 1000
# num check samples 1024
# num check samples 1000
# num check samples 1024
# ...

# %%
# %%bash
# # replace film_flatqa with the script that runs the model we want
# source activate sysgen
# dos2unix scripts/train/hypervqa_flatqa.sh
# chmod +x scripts/train/hypervqa_flatqa.sh
# export NMN=/content/drive/MyDrive/CSC413-HyperVQA
#
# scripts/train/hypervqa_flatqa.sh --data_dir data/sqoop-variety_4-repeats_7500/ --checkpoint_path models/v4_model.pt\ --batch_size 256 --num_iterations 15000
# Out:
# path: ['/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA/scripts', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '../', '/content/drive/MyDrive/CSC413/']
# training device: cuda:0
# Reading features from  data/sqoop-variety_4-repeats_7500/train_features.h5
# Reading questions from  data/sqoop-variety_4-repeats_7500/train_questions.h5
# Reading question data into memory
# Reading features from  data/sqoop-variety_4-repeats_7500/val_features.h5
# Reading questions from  data/sqoop-variety_4-repeats_7500/val_questions.h5
# Reading question data into memory
# num check samples 1024
# num check samples 1000
# num check samples 1024
# num check samples 1000
# num check samples 1024
# ...

# %%
# %%bash
# # replace film_flatqa with the script that runs the model we want
# source activate sysgen
# dos2unix scripts/train/hypervqa_flatqa.sh
# chmod +x scripts/train/hypervqa_flatqa.sh
# export NMN=/content/drive/MyDrive/CSC413-HyperVQA
#
# scripts/train/hypervqa_flatqa.sh --data_dir data/sqoop-variety_8-repeats_3750/ --checkpoint_path models/v8_model.pt\ --batch_size 256 --num_iterations 15000
# Out:
# path: ['/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA/scripts', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '../', '/content/drive/MyDrive/CSC413/']
# training device: cuda:0
# Reading features from  data/sqoop-variety_8-repeats_3750/train_features.h5
# Reading questions from  data/sqoop-variety_8-repeats_3750/train_questions.h5
# Reading question data into memory
# Reading features from  data/sqoop-variety_8-repeats_3750/val_features.h5
# Reading questions from  data/sqoop-variety_8-repeats_3750/val_questions.h5
# Reading question data into memory
# num check samples 1024
# num check samples 1000
# num check samples 1024
# num check samples 1000
# num check samples 1024
# ...

# %%
# %%bash
# # replace film_flatqa with the script that runs the model we want
# source activate sysgen
# dos2unix scripts/train/hypervqa_flatqa.sh
# chmod +x scripts/train/hypervqa_flatqa.sh
# export NMN=/content/drive/MyDrive/CSC413-HyperVQA
#
# scripts/train/hypervqa_flatqa.sh --data_dir data/sqoop-variety_18-repeats_2000/ --checkpoint_path models/v18_model.pt\ --batch_size 256 --num_iterations 20000
# Out:
# path: ['/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA/scripts', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '../', '/content/drive/MyDrive/CSC413/']
# training device: cuda:0
# Reading features from  data/sqoop-variety_18-repeats_2000/train_features.h5
# Reading questions from  data/sqoop-variety_18-repeats_2000/train_questions.h5
# Reading question data into memory
# Reading features from  data/sqoop-variety_18-repeats_2000/val_features.h5
# Reading questions from  data/sqoop-variety_18-repeats_2000/val_questions.h5
# Reading question data into memory
# num check samples 1024
# num check samples 1000
# num check samples 1024
# num check samples 1000
# num check samples 1024
# ...

# %%
# %%bash
# # replace film_flatqa with the script that runs the model we want
# source activate sysgen
# dos2unix scripts/train/hypervqa_flatqa.sh
# chmod +x scripts/train/hypervqa_flatqa.sh
# export NMN=/content/drive/MyDrive/CSC413-HyperVQA
#
# scripts/train/hypervqa_flatqa.sh --data_dir data/sqoop-variety_35-repeats_1000_vanilla/ --checkpoint_path models/v35_model.pt\ --batch_size 512 --num_iterations 20000
# Out:
# path: ['/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA/scripts', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/.shortcut-targets-by-id/1_vBpec5_YolQj3ewatcUQU64g1njb8-u/CSC413-HyperVQA', '../', '/content/drive/MyDrive/CSC413/']
# training device: cuda:0
# Reading features from  data/sqoop-variety_35-repeats_1000_vanilla/train_features.h5
# Reading questions from  data/sqoop-variety_35-repeats_1000_vanilla/train_questions.h5
# Reading question data into memory
# Reading features from  data/sqoop-variety_35-repeats_1000_vanilla/val_features.h5
# Reading questions from  data/sqoop-variety_35-repeats_1000_vanilla/val_questions.h5
# Reading question data into memory
# num check samples 1024
# num check samples 1000
# num check samples 1024
# num check samples 1000
# ...
